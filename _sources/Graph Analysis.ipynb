# %%
# !pip install networkx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (3.1)

# %%
import networkx as nx
G=nx.Graph()
G.add_edges_from([(1,2),(1,3),(1,4),(2,3),(3,4),(4,5),(4,6),(5,6),(5,7),(5,8),(6,7),(6,8),(7,8),(7,9)])
# G=nx.dodecahedral_graph()
nx.draw(G)
# nx.draw(G,pos=nx.spring_layout(G))

# %%
# degree centrality
nx.degree_centrality(G)
# Out:
# {1: 0.375,
#  2: 0.25,
#  3: 0.375,
#  4: 0.5,
#  5: 0.5,
#  6: 0.5,
#  7: 0.5,
#  8: 0.375,
#  9: 0.125}

# %%
#Closeness centrality
nx.closeness_centrality(G)
# Out:
# {1: 0.47058823529411764,
#  2: 0.34782608695652173,
#  3: 0.47058823529411764,
#  4: 0.6153846153846154,
#  5: 0.6153846153846154,
#  6: 0.6153846153846154,
#  7: 0.5,
#  8: 0.47058823529411764,
#  9: 0.34782608695652173}

# %%
#Betweenness centrality
nx.betweenness_centrality(G)
# Out:
# {1: 0.10714285714285714,
#  2: 0.0,
#  3: 0.10714285714285714,
#  4: 0.5357142857142857,
#  5: 0.21428571428571427,
#  6: 0.21428571428571427,
#  7: 0.25,
#  8: 0.0,
#  9: 0.0}

# %%
#Load centrality
nx.load_centrality(G)
# Out:
# {1: 0.10714285714285714,
#  2: 0.0,
#  3: 0.10714285714285714,
#  4: 0.5357142857142857,
#  5: 0.21428571428571427,
#  6: 0.21428571428571427,
#  7: 0.25,
#  8: 0.0,
#  9: 0.0}

# %%
#EigenVektor centrality
nx.eigenvector_centrality(G)
# Out:
# {1: 0.19575404149708636,
#  2: 0.11168805432964159,
#  3: 0.19575404149708636,
#  4: 0.3787510773733839,
#  5: 0.4680839101306904,
#  6: 0.4680839101306904,
#  7: 0.4099765880693859,
#  8: 0.38401792296324566,
#  9: 0.11695489991950335}
